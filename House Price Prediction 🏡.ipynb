# %% [markdown]
# # Housing price prediction
# - In this dataset we have to predict the final prices of the houses from features given

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('H:\\Level 4 Information Systems\\first term\\Machine Learning\\Assignment1\\house_data.csv')
data
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  grade  view      lat  waterfront  ...  floors  sqft_above  \
# 0             1180      7     0  47.5112           0  ...     1.0        1180
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   grade          21613 non-null  int64
#  7   view           21613 non-null  int64
#  8   lat            21613 non-null  float64
#  9   waterfront     21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  floors         21613 non-null  float64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'grade',
#        'view', 'lat', 'waterfront', 'condition', 'floors', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'sqft_lot',
#        'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %% [markdown]
# # Esploratory Data Analysis

# %%
plt.figure(figsize=(10,10))
sns.jointplot(x=data.lat.values, y=data.long.values, size=10)
plt.ylabel('Longitude', fontsize=12)
plt.xlabel('Latitude', fontsize=12)
plt.show()
plt1 = plt()
sns.despine
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\CL68B4~1\AppData\Local\Temp/ipykernel_5736/3653274182.py in <module>
#       4 plt.xlabel('Latitude', fontsize=12)
#       5 plt.show()
# ----> 6 plt1 = plt()
#       7 sns.despine
#
# TypeError: 'module' object is not callable

# %%
plt.figure(figsize = (25,35))

plt.subplot(4,2,1)
plt.scatter(data_df.price,data_df.long)
plt.title("Price vs Location of the area")

plt.subplot(4,2,2)
plt.scatter(data.price,data.lat)
plt.xlabel("Price")
plt.ylabel('Latitude')
plt.title("Latitude vs Price")

plt.subplot(4,2,3)
plt.scatter(data.price,data.lat)
plt.xlabel("Price")
plt.ylabel('Latitude')
plt.title("Latitude vs Price")

plt.subplot(4,2,4)
plt.scatter(data.bedrooms,data.price)
plt.title("Bedroom and Price ")
plt.xlabel("Bedrooms")
plt.ylabel("Price")
plt.show()
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.figure(figsize = (25,35))

plt.subplot(4,2,1)
plt.scatter((data['sqft_living']+data['sqft_basement']),data['price'])

plt.subplot(4,2,2)
plt.scatter(data.waterfront,data.price)
plt.title("Waterfront vs Price ( 0= no waterfront)")

plt.subplot(4,2,3)
data.floors.value_counts().plot(kind='bar')

plt.subplot(4,2,4)
plt.scatter(data.zipcode,data.price)
plt.title("Which is the pricey location by zipcode?")
# Out:
# Text(0.5, 1.0, 'Which is the pricey location by zipcode?')

# %% [markdown]
# # Correlation Matrix (Feature Selection)
# - it seems that most of the features are good features to our model
# - Positive Relationship between price and other features

# %%
corr = data.corr()
plt.figure(figsize=(15,10))
sns.heatmap(corr, annot=True);

# %% [markdown]
# # Build Model

# %%
reg = LinearRegression()

labels = data['price']
conv_dates = [1 if values == 2014 else 0 for values in data.date ]
data['date'] = conv_dates
train1 = data.drop(['id', 'price'],axis=1)

# %%
x_train , x_test , y_train , y_test = train_test_split(train1 , labels , test_size = 0.10,random_state =2)

reg.fit(x_train,y_train)

predictions = reg.predict(x_test)

# %% [markdown]
# # Evaluate Model

# %%
# model evaluation
print('mean_squared_error : ', mean_squared_error(y_test, predictions))
print('mean_absolute_error : ', mean_absolute_error(y_test, predictions))
print("Model Accuracy : ", round(reg.score(x_test,y_test),5)*100,"%")
# Out:
# mean_squared_error :  39187574448.87776
# mean_absolute_error :  127017.03586904642
# Model Accuracy :  73.207 %

# %%
predictions = predictions.astype('int64')

# %%
pred_y_df_2 = pd.DataFrame({'Actual Value' : y_test, 'predicted value' : predictions, "Difference" :predictions- y_test})
pred_y_df_2[0:20]
# Out:
#        Actual Value  predicted value  Difference
# 6638       735000.0           709181    -25819.0
# 7366      1150000.0          1454576    304576.0
# 3158       350500.0           422613     72113.0
# 9117       860000.0          1281894    421894.0
# 3392       122000.0           -31908   -153908.0
# 305        725000.0           699790    -25210.0
# 14462      417000.0           653414    236414.0
# 6196       594950.0           540555    -54395.0
# 10194      471000.0           414295    -56705.0
# 13457      634950.0           837503    202553.0
# 8698       500000.0           589108     89108.0
# 18573      768000.0           751750    -16250.0
# 6675       323000.0           335772     12772.0
# 4287       430000.0           529370     99370.0
# 3604       625000.0           647666     22666.0
# 7168       710000.0           571449   -138551.0
# 16322      620000.0           509885   -110115.0
# 11024      665000.0           942126    277126.0
# ...
